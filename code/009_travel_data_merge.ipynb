# %%
import pandas as pd

df = pd.read_parquet('../data/Player-Games with Injuries.parquet')
df.head()
# Out:
#   firstName lastName  personId    gameId gameDateTimeEst_player  \
# 0     Grant     Hill     255.0  21000521    2011-01-05 22:30:00
# 1     Grant     Hill     255.0  21000533    2011-01-07 22:30:00
# 2     Grant     Hill     255.0  21000584    2011-01-14 22:30:00
# 3     Grant     Hill     255.0  21000598    2011-01-17 13:00:00
# 4     Grant     Hill     255.0  21000613    2011-01-19 19:00:00
#
#   playerteamName gameType_player  win_player  home_player  numMinutes_player  \
# 0           Suns  Regular Season         0.0          1.0               34.0
# 1           Suns  Regular Season         0.0          1.0               29.0
# 2           Suns  Regular Season         1.0          1.0               36.0
# 3           Suns  Regular Season         1.0          0.0               37.0
# 4           Suns  Regular Season         1.0          0.0               40.0
#
#    ...  rolling_7g_points_per36  rolling_7g_assists_per36  \
# 0  ...                      NaN                       NaN
# 1  ...                 0.294118                  0.058824
# 2  ...                 0.319473                  0.063895
# 3  ...                 0.407426                  0.070374
# 4  ...                 0.474489                  0.066294
#
#    rolling_7g_blocks_per36  rolling_7g_steals_per36  \
# 0                      NaN                      NaN
# 1                 0.029412                 0.000000
# 2                 0.031947                 0.034483
# 3                 0.021298                 0.022989
# 4                 0.015974                 0.017241
#
#    rolling_7g_3p_relative_percent  rolling_7g_ft_relative_percent  \
# 0                             NaN                             NaN
# 1                       -0.478000                        0.294000
# 2                       -0.364000                        0.123500
# 3                       -0.084667                        0.030333
# 4                       -0.027750                        0.026250
#
#    rolling_7g_USG  days_rest  back_to_back  games_last_14d
# 0             NaN        NaN             0             NaN
# 1       21.420304        2.0             0             1.0
# 2       21.999625        7.0             0             2.0
# 3       22.576589        2.0             0             3.0
# 4       22.523480        2.0             0             4.0
#
# [5 rows x 147 columns]

# %%
travel_df = pd.read_parquet('../data/nba_travel.parquet')
travel_df.head()
# Out:
#     season season_type      team_name team_abbrev     game_id  game_date  \
# 0  2009-10          RS  Atlanta Hawks         ATL  0021000008 2010-10-27
# 1  2009-10          RS  Atlanta Hawks         ATL  0021000021 2010-10-29
# 2  2009-10          RS  Atlanta Hawks         ATL  0021000031 2010-10-30
# 3  2009-10          RS  Atlanta Hawks         ATL  0021000047 2010-11-02
# 4  2009-10          RS  Atlanta Hawks         ATL  0021000054 2010-11-03
#
#   month  week opponent_abbrev location  ... distance_miles      route  \
# 0   Oct    43             MEM     Away  ...          336.5  ATL → MEM
# 1   Oct    43             PHI     Away  ...          879.4  MEM → PHI
# 2   Oct    43             WAS     Home  ...          663.4  PHI → ATL
# 3   Nov    44             CLE     Away  ...          553.9  ATL → CLE
# 4   Nov    44             DET     Home  ...          553.9  CLE → ATL
#
#    direction_ew  return_home   timezone_origin     timezone_dest tz_shift_hrs  \
# 0          West           No  America/New_York   America/Chicago         -1.0
# 1          East           No   America/Chicago  America/New_York          1.0
# 2          West           No  America/New_York  America/New_York          0.0
# 3          East           No  America/New_York  America/New_York          0.0
# 4          West           No  America/New_York  America/New_York          0.0
#
#   rest_days flight_time flight_minutes
# 0       NaN      0h 36m           36.7
# 1       1.0      1h 35m           95.9
# 2       0.0      1h 12m           72.4
# 3       2.0      1h 00m           60.4
# 4       0.0      1h 00m           60.4
#
# [5 rows x 25 columns]

# %%
travel_df['playerteamName'] = travel_df['team_name'].apply(
    lambda x: x.split(' ')[-1]
)

travel_df['playerteamName'] = travel_df['playerteamName'].replace({
    'Blazers': 'Trail Blazers'
})

# %%
df['game_date'] = pd.to_datetime(df['gameDateTimeEst_player']).dt.normalize()

# %%
travel_df['game_date']
# Out:
# 0       2010-10-27
# 1       2010-10-29
# 2       2010-10-30
# 3       2010-11-02
# 4       2010-11-03
#            ...
# 40969   2026-04-05
# 40970   2026-04-07
# 40971   2026-04-09
# 40972   2026-04-10
# 40973   2026-04-12
# Name: game_date, Length: 40974, dtype: datetime64[ns]

# %%
df = pd.merge(
    df,
    travel_df,
    on=['playerteamName', 'game_date'],
    how='left',
    indicator=True
)

missing = df[df['_merge'] == 'left_only']

print(len(missing))
# Out:
# 50

# %%
df = df.drop(columns=['_merge'])
missing[['playerteamName', 'game_date']].value_counts()

# %% [markdown]
# These are the NBA Cup Finals games, so they happened in Vegas instead of the typical locations. That's fine for our purposes - we can explain that.

# %%
import matplotlib.pyplot as plt

plt.hist(df['flight_minutes'])
# Out:
# (array([126533.,  61644.,  49481.,  43109.,  21764.,  12547.,   8583.,
#           4087.,   2757.,   2603.]),
#  array([  0.  ,  29.53,  59.06,  88.59, 118.12, 147.65, 177.18, 206.71,
#         236.24, 265.77, 295.3 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

sns.regplot(x=df['flight_minutes'], y = df['days_to_next_injury'], scatter=False)
# Out:
# <Axes: xlabel='flight_minutes', ylabel='days_to_next_injury'>

# %%
sns.regplot(x=df['tz_shift_hrs'], y=df['days_to_next_injury'], scatter=False)
# Out:
# <Axes: xlabel='tz_shift_hrs', ylabel='days_to_next_injury'>

# %%
sns.regplot(x=abs(df['tz_shift_hrs']), y=df['days_to_next_injury'], scatter=False)
# Out:
# <Axes: xlabel='tz_shift_hrs', ylabel='days_to_next_injury'>

# %%
df['tz_shift_hrs'] = abs(df['tz_shift_hrs'])
df = df.drop(columns = [
    'game_id', 'game_date',	'month', 'week', 'opponent_abbrev', 'location'
])
for c in df.columns:
    print(c)
# Out:
# firstName
# lastName
# personId
# gameId
# gameDateTimeEst_player
# playerteamName
# gameType_player
# win_player
# home_player
# numMinutes_player
# points_player
# assists_player
# blocks_player
# steals_player
# fieldGoalsAttempted_player
# fieldGoalsMade_player
# fieldGoalsPercentage_player
# threePointersAttempted_player
# threePointersMade_player
# threePointersPercentage_player
# freeThrowsAttempted_player
# freeThrowsMade_player
# freeThrowsPercentage_player
# reboundsDefensive_player
# reboundsOffensive_player
# reboundsTotal_player
# foulsPersonal_player
# turnovers_player
# plusMinusPoints_player
# playerteamId_player
# comment
# points_per36
# assists_per36
# blocks_per36
# steals_per36
# fieldGoalsAttempted_per36
# fieldGoalsMade_per36
# threePointersAttempted_per36
# threePointersMade_per36
# freeThrowsAttempted_per36
# freeThrowsMade_per36
# reboundsDefensive_per36
# reboundsOffensive_per36
# reboundsTotal_per36
# foulsPersonal_per36
# turnovers_per36
# plusMinusPoints_per36
# season_x
# playerteamId_team
# points_team
# assists_team
# blocks_team
# steals_team
# fieldGoalsAttempted_team
# fieldGoalsMade_team
# fieldGoalsPercentage_team
# threePointersAttempted_team
# threePointersMade_team
# threePointersPercentage_team
# freeThrowsAttempted_team
# freeThrowsMade_team
# freeThrowsPercentage_team
# reboundsDefensive_team
# reboundsOffensive_team
# reboundsTotal_team
# foulsPersonal_team
# turnovers_team
# plusMinusPoints_team
# numMinutes_team
# benchPoints
# pointsFastBreak
# pointsFromTurnovers
# pointsInThePaint
# pointsSecondChance
# coachId
# reboundsTeam
# turnoversTeam
# pointDifferential
# winPercent_team
# pointsPercent
# assistsPercent
# stealsPercent
# fieldGoalsAttemptedPercent
# fieldGoalsMadePercent
# freeThrowsAttemptedPercent
# freeThrowsMadePercent
# reboundsDefensivePercent
# reboundsOffensivePercent
# reboundsTotalPercent
# foulsPersonalPercent
# turnoversPercent
# fgRelativePercent
# 3pRelativePercent
# ftRelativePercent
# 3PA_rate
# trueShooting
# eFG
# FTA_rate
# USG
# Position
# positionless_index
# Name
# days_to_next_injury
# injury_within_7d
# injury_within_14d
# injury_within_30d
# rolling_3g_minutes
# rolling_3g_points
# rolling_3g_assists
# rolling_3g_rebounds
# rolling_3g_steals
# rolling_3g_blocks
# rolling_3g_turnovers
# rolling_3g_field_goals_made
# rolling_3g_field_goals_attempted
# rolling_3g_three_pointers_made
# rolling_3g_three_pointers_attempted
# rolling_3g_three_point_percent
# rolling_3g_points_per36
# rolling_3g_assists_per36
# rolling_3g_blocks_per36
# rolling_3g_steals_per36
# rolling_3g_3p_relative_percent
# rolling_3g_ft_relative_percent
# rolling_3g_USG
# rolling_7g_minutes
# rolling_7g_points
# rolling_7g_assists
# rolling_7g_rebounds
# rolling_7g_steals
# rolling_7g_blocks
# rolling_7g_turnovers
# rolling_7g_field_goals_made
# rolling_7g_field_goals_attempted
# rolling_7g_three_pointers_made
# rolling_7g_three_pointers_attempted
# rolling_7g_three_point_percent
# rolling_7g_points_per36
# rolling_7g_assists_per36
# rolling_7g_blocks_per36
# rolling_7g_steals_per36
# rolling_7g_3p_relative_percent
# rolling_7g_ft_relative_percent
# rolling_7g_USG
# days_rest
# back_to_back
# games_last_14d
# season_y
# season_type
# team_name
# team_abbrev
# wl
# origin_lat
# origin_lon
# dest_lat
# dest_lon
# distance_miles
# route
# direction_ew
# return_home
# timezone_origin
# timezone_dest
# tz_shift_hrs
# rest_days
# flight_time
# flight_minutes

# %%
for v in df['direction_ew'].unique():
    if v == None:
        continue
    print(v)
    print(df[df['direction_ew']==v]['days_to_next_injury'].mean())
# Out:
# East
# 38.73959314611605
# N/A
# 38.299903283004674
# West
# 38.90291090707295
# nan
# nan

# %% [markdown]
# East/West flights don't seem to make a difference

# %%
df = df.drop(columns=['season_y', 'playerteamId_team', 'firstName',
                      'lastName', 'wl', 'season_type', 'team_name',
                      'team_abbrev', 'origin_lat', 'origin_lon',
                      'dest_lat', 'dest_lon', 'timezone_origin',
                      'timezone_dest', 'flight_time', 'route', 
                      'return_home', 'days_rest'])
# Out:
# personId
# gameId
# gameDateTimeEst_player
# playerteamName
# gameType_player
# win_player
# home_player
# numMinutes_player
# points_player
# assists_player
# blocks_player
# steals_player
# fieldGoalsAttempted_player
# fieldGoalsMade_player
# fieldGoalsPercentage_player
# threePointersAttempted_player
# threePointersMade_player
# threePointersPercentage_player
# freeThrowsAttempted_player
# freeThrowsMade_player
# freeThrowsPercentage_player
# reboundsDefensive_player
# reboundsOffensive_player
# reboundsTotal_player
# foulsPersonal_player
# turnovers_player
# plusMinusPoints_player
# playerteamId_player
# comment
# points_per36
# assists_per36
# blocks_per36
# steals_per36
# fieldGoalsAttempted_per36
# fieldGoalsMade_per36
# threePointersAttempted_per36
# threePointersMade_per36
# freeThrowsAttempted_per36
# freeThrowsMade_per36
# reboundsDefensive_per36
# reboundsOffensive_per36
# reboundsTotal_per36
# foulsPersonal_per36
# turnovers_per36
# plusMinusPoints_per36
# season_x
# points_team
# assists_team
# blocks_team
# steals_team
# fieldGoalsAttempted_team
# fieldGoalsMade_team
# fieldGoalsPercentage_team
# threePointersAttempted_team
# threePointersMade_team
# threePointersPercentage_team
# freeThrowsAttempted_team
# freeThrowsMade_team
# freeThrowsPercentage_team
# reboundsDefensive_team
# reboundsOffensive_team
# reboundsTotal_team
# foulsPersonal_team
# turnovers_team
# plusMinusPoints_team
# numMinutes_team
# benchPoints
# pointsFastBreak
# pointsFromTurnovers
# pointsInThePaint
# pointsSecondChance
# coachId
# reboundsTeam
# turnoversTeam
# pointDifferential
# winPercent_team
# pointsPercent
# assistsPercent
# stealsPercent
# fieldGoalsAttemptedPercent
# fieldGoalsMadePercent
# freeThrowsAttemptedPercent
# freeThrowsMadePercent
# reboundsDefensivePercent
# reboundsOffensivePercent
# reboundsTotalPercent
# foulsPersonalPercent
# turnoversPercent
# fgRelativePercent
# 3pRelativePercent
# ftRelativePercent
# 3PA_rate
# trueShooting
# eFG
# FTA_rate
# USG
# Position
# positionless_index
# Name
# days_to_next_injury
# injury_within_7d
# injury_within_14d
# injury_within_30d
# rolling_3g_minutes
# rolling_3g_points
# rolling_3g_assists
# rolling_3g_rebounds
# rolling_3g_steals
# rolling_3g_blocks
# rolling_3g_turnovers
# rolling_3g_field_goals_made
# rolling_3g_field_goals_attempted
# rolling_3g_three_pointers_made
# rolling_3g_three_pointers_attempted
# rolling_3g_three_point_percent
# rolling_3g_points_per36
# rolling_3g_assists_per36
# rolling_3g_blocks_per36
# rolling_3g_steals_per36
# rolling_3g_3p_relative_percent
# rolling_3g_ft_relative_percent
# rolling_3g_USG
# rolling_7g_minutes
# rolling_7g_points
# rolling_7g_assists
# rolling_7g_rebounds
# rolling_7g_steals
# rolling_7g_blocks
# rolling_7g_turnovers
# rolling_7g_field_goals_made
# rolling_7g_field_goals_attempted
# rolling_7g_three_pointers_made
# rolling_7g_three_pointers_attempted
# rolling_7g_three_point_percent
# rolling_7g_points_per36
# rolling_7g_assists_per36
# rolling_7g_blocks_per36
# rolling_7g_steals_per36
# rolling_7g_3p_relative_percent
# rolling_7g_ft_relative_percent
# rolling_7g_USG
# days_rest
# back_to_back
# games_last_14d
# distance_miles
# route
# direction_ew
# return_home
# tz_shift_hrs
# rest_days
# flight_minutes
